# %% [markdown]
# # Fetching Data From Binance API

# %%
import pandas as pd
import config
from binance.client import Client

# %%
api_key = config.api_key
api_secret = config.api_secret

client = Client(api_key, api_secret)

# %% [markdown]
# ## BTC-USDT Spot Market Data

# %%
# Function to fetch spot market data
def fetch_binance_spot_data(symbol, interval, start_str, end_str):
    klines = client.get_historical_klines(symbol, interval, start_str, end_str)
    df = pd.DataFrame(klines, columns=[
        'timestamp', 'open', 'high', 'low', 'close', 'volume',
        'close_time', 'quote_asset_volume', 'number_of_trades',
        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
    ])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)
    df = df.astype(float)
    return df

# %%
# Parameters
symbol_spot = 'BTCUSDT'
interval_spot = Client.KLINE_INTERVAL_15MINUTE
start_str_spot = '2021-01-01'
end_str_spot = '2024-06-15'

# %%
# Fetch the data and save to CSV
df_spot = fetch_binance_spot_data(symbol_spot, interval_spot, start_str_spot, end_str_spot)
df_spot.to_csv('data/btc_usdt_spot_data.csv')
df_spot.head()
# Out:
#                          open      high       low     close       volume  \
# timestamp
# 2021-01-01 00:00:00  28923.63  29017.50  28690.17  28752.80   840.077569
# 2021-01-01 00:15:00  28752.80  28875.55  28720.91  28836.63   480.611179
# 2021-01-01 00:30:00  28836.63  28943.87  28836.62  28930.11   471.134708
# 2021-01-01 00:45:00  28930.11  29031.34  28889.99  28995.13   519.987989
# 2021-01-01 01:00:00  28995.13  29385.00  28960.35  29382.59  1735.839005
#
#                        close_time  quote_asset_volume  number_of_trades  \
# timestamp
# 2021-01-01 00:00:00  1.609460e+12        2.423972e+07           19318.0
# 2021-01-01 00:15:00  1.609461e+12        1.384695e+07           13876.0
# 2021-01-01 00:30:00  1.609462e+12        1.361619e+07           12234.0
# 2021-01-01 00:45:00  1.609463e+12        1.506597e+07           12961.0
# 2021-01-01 01:00:00  1.609464e+12        5.068079e+07           32696.0
#
#                      taker_buy_base_asset_volume  \
# timestamp
# 2021-01-01 00:00:00                   393.704224
# 2021-01-01 00:15:00                   235.967978
# 2021-01-01 00:30:00                   307.966715
# 2021-01-01 00:45:00                   277.720321
# 2021-01-01 01:00:00                  1152.696972
#
#                      taker_buy_quote_asset_volume  ignore
# timestamp
# 2021-01-01 00:00:00                  1.136006e+07     0.0
# 2021-01-01 00:15:00                  6.798117e+06     0.0
# 2021-01-01 00:30:00                  8.899807e+06     0.0
# 2021-01-01 00:45:00                  8.045564e+06     0.0
# 2021-01-01 01:00:00                  3.366289e+07     0.0

# %% [markdown]
# ## BTC-USDT Futures Market Data

# %%
# Function to fetch futures market data
def fetch_binance_futures_data(client, symbol, interval, start_str, end_str):
    klines = client.futures_historical_klines(symbol, interval, start_str, end_str)
    df = pd.DataFrame(klines, columns=[
        'timestamp', 'open', 'high', 'low', 'close', 'volume',
        'close_time', 'quote_asset_volume', 'number_of_trades',
        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
    ])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)
    df = df.astype(float)
    return df

# %%
# Parameters
symbol_futures = 'BTCUSDT'
interval_futures = Client.KLINE_INTERVAL_15MINUTE
start_str_futures = '2021-01-01'
end_str_futures = '2024-06-15'

# %%
# Fetch the data
df_futures = fetch_binance_futures_data(client, symbol_futures, interval_futures, start_str_futures, end_str_futures)
df_futures.to_csv('data/btc_usdt_futures_data.csv')
df_futures.head()
# Out:
#                          open      high       low     close    volume  \
# timestamp
# 2021-01-01 00:00:00  28948.19  29045.93  28706.00  28786.75  3181.960
# 2021-01-01 00:15:00  28786.92  28902.68  28752.30  28859.28  2215.315
# 2021-01-01 00:30:00  28860.00  28968.49  28859.99  28947.61  1153.678
# 2021-01-01 00:45:00  28947.61  29055.00  28910.94  29015.00  1486.635
# 2021-01-01 01:00:00  29015.00  29499.00  28975.46  29446.35  7476.067
#
#                        close_time  quote_asset_volume  number_of_trades  \
# timestamp
# 2021-01-01 00:00:00  1.609460e+12        9.183460e+07           24166.0
# 2021-01-01 00:15:00  1.609461e+12        6.386520e+07           17044.0
# 2021-01-01 00:30:00  1.609462e+12        3.336960e+07           12208.0
# 2021-01-01 00:45:00  1.609463e+12        4.309520e+07           12524.0
# 2021-01-01 01:00:00  1.609464e+12        2.187655e+08           45858.0
#
#                      taker_buy_base_asset_volume  \
# timestamp
# 2021-01-01 00:00:00                     1277.389
# 2021-01-01 00:15:00                     1209.372
# 2021-01-01 00:30:00                      620.757
# 2021-01-01 00:45:00                      876.324
# 2021-01-01 01:00:00                     4619.428
#
#                      taker_buy_quote_asset_volume  ignore
# timestamp
# 2021-01-01 00:00:00                  3.689901e+07     0.0
# 2021-01-01 00:15:00                  3.486977e+07     0.0
# 2021-01-01 00:30:00                  1.795427e+07     0.0
# 2021-01-01 00:45:00                  2.540813e+07     0.0
# 2021-01-01 01:00:00                  1.352136e+08     0.0
