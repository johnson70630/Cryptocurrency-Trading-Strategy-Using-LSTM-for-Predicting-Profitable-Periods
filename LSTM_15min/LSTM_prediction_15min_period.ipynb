# %% [markdown]
# # LSTM prediction

# %% [markdown]
# ## Access the file in Google Drive

# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Get to the folder we are at
FOLDERNAME = 'Colab\ Notebooks/Quantitative_trading_project/15min_data_prediction'
# %cd drive/MyDrive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Quantitative_trading_project/15min_data_prediction

# %%
# Define device
import torch
if torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')
print('Device:', device)
# Out:
# Device: cpu

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Pre-processing

# %%
# Load data
btc_spot = pd.read_csv('data/btc_usdt_spot_data.csv')
btc_futures = pd.read_csv('data/btc_usdt_futures_data.csv')
indicators = pd.read_csv('data/indicators.csv')
true_label = pd.read_csv('data/period_labels.csv')

# %%
btc_spot.head()
# print(btc_spot.columns)
# Out:
#              timestamp      open      high       low     close       volume  \
# 0  2021-01-01 00:00:00  28923.63  29017.50  28690.17  28752.80   840.077569
# 1  2021-01-01 00:15:00  28752.80  28875.55  28720.91  28836.63   480.611179
# 2  2021-01-01 00:30:00  28836.63  28943.87  28836.62  28930.11   471.134708
# 3  2021-01-01 00:45:00  28930.11  29031.34  28889.99  28995.13   519.987989
# 4  2021-01-01 01:00:00  28995.13  29385.00  28960.35  29382.59  1735.839005
#
#      close_time  quote_asset_volume  number_of_trades  \
# 0  1.609460e+12        2.423972e+07           19318.0
# 1  1.609461e+12        1.384695e+07           13876.0
# 2  1.609462e+12        1.361619e+07           12234.0
# 3  1.609463e+12        1.506597e+07           12961.0
# 4  1.609464e+12        5.068079e+07           32696.0
#
#    taker_buy_base_asset_volume  taker_buy_quote_asset_volume  ignore
# 0                   393.704224                  1.136006e+07     0.0
# 1                   235.967978                  6.798117e+06     0.0
# 2                   307.966715                  8.899807e+06     0.0
# 3                   277.720321                  8.045564e+06     0.0
# 4                  1152.696972                  3.366289e+07     0.0

# %%
# Drop unnecessary columns
columns_to_drop = ['close_time', 'ignore']
btc_spot.drop(columns=columns_to_drop, inplace=True)
btc_futures.drop(columns=columns_to_drop, inplace=True)

# %%
# btc_spot.head()
# print(btc_spot.columns)

# %%
# Set timestamp as index and convert to datetime
btc_spot['timestamp'] = pd.to_datetime(btc_spot['timestamp'])
btc_spot.set_index('timestamp', inplace=True)
btc_futures['timestamp'] = pd.to_datetime(btc_futures['timestamp'])
btc_futures.set_index('timestamp', inplace=True)
indicators['timestamp'] = pd.to_datetime(indicators['timestamp'])
indicators.set_index('timestamp', inplace=True)
true_label['time'] = pd.to_datetime(true_label['time'])
true_label.set_index('time', inplace=True)

# %%
def rename_col(df, name):
  for column in df.columns:
    df.rename(columns={column: f'{name}_{column}'}, inplace=True)
  return df

# %%
btc_spot = rename_col(btc_spot, 'btc_spot')
btc_futures = rename_col(btc_futures, 'btc_futures')

# %%
# shift because we aim to predict the label for next K bar
true_label = true_label.shift(-1)

# Merge DataFrames on the timestamp index
df = pd.concat([true_label, btc_spot, btc_futures, indicators], axis=1)
df.head()
# Out:
#                      label  btc_spot_open  btc_spot_high  btc_spot_low  \
# 2021-01-01 00:00:00    NaN       28923.63       29017.50      28690.17
# 2021-01-01 00:15:00    NaN       28752.80       28875.55      28720.91
# 2021-01-01 00:30:00    NaN       28836.63       28943.87      28836.62
# 2021-01-01 00:45:00    NaN       28930.11       29031.34      28889.99
# 2021-01-01 01:00:00    NaN       28995.13       29385.00      28960.35
#
#                      btc_spot_close  btc_spot_volume  \
# 2021-01-01 00:00:00        28752.80       840.077569
# 2021-01-01 00:15:00        28836.63       480.611179
# 2021-01-01 00:30:00        28930.11       471.134708
# 2021-01-01 00:45:00        28995.13       519.987989
# 2021-01-01 01:00:00        29382.59      1735.839005
#
#                      btc_spot_quote_asset_volume  btc_spot_number_of_trades  \
# 2021-01-01 00:00:00                 2.423972e+07                    19318.0
# 2021-01-01 00:15:00                 1.384695e+07                    13876.0
# 2021-01-01 00:30:00                 1.361619e+07                    12234.0
# 2021-01-01 00:45:00                 1.506597e+07                    12961.0
# 2021-01-01 01:00:00                 5.068079e+07                    32696.0
#
#                      btc_spot_taker_buy_base_asset_volume  \
# 2021-01-01 00:00:00                            393.704224
# 2021-01-01 00:15:00                            235.967978
# 2021-01-01 00:30:00                            307.966715
# 2021-01-01 00:45:00                            277.720321
# 2021-01-01 01:00:00                           1152.696972
#
#                      btc_spot_taker_buy_quote_asset_volume  ...        obv  \
# 2021-01-01 00:00:00                           1.136006e+07  ...   3181.960
# 2021-01-01 00:15:00                           6.798117e+06  ...   5397.275
# 2021-01-01 00:30:00                           8.899807e+06  ...   6550.953
# 2021-01-01 00:45:00                           8.045564e+06  ...   8037.588
# 2021-01-01 01:00:00                           3.366289e+07  ...  15513.655
#
#                      cmf  williams  parabolic_sar  vwap  fibonacci_0.236  \
# 2021-01-01 00:00:00  NaN       NaN       28786.75   NaN              NaN
# 2021-01-01 00:15:00  NaN       NaN       28859.28   NaN              NaN
# 2021-01-01 00:30:00  NaN       NaN       29045.93   NaN              NaN
# 2021-01-01 00:45:00  NaN       NaN       28859.99   NaN              NaN
# 2021-01-01 01:00:00  NaN       NaN       28859.99   NaN              NaN
#
#                      fibonacci_0.382  fibonacci_0.5  fibonacci_0.618  \
# 2021-01-01 00:00:00              NaN            NaN              NaN
# 2021-01-01 00:15:00              NaN            NaN              NaN
# 2021-01-01 00:30:00              NaN            NaN              NaN
# 2021-01-01 00:45:00              NaN            NaN              NaN
# 2021-01-01 01:00:00              NaN            NaN              NaN
#
#                      fibonacci_0.764
# 2021-01-01 00:00:00              NaN
# 2021-01-01 00:15:00              NaN
# 2021-01-01 00:30:00              NaN
# 2021-01-01 00:45:00              NaN
# 2021-01-01 01:00:00              NaN
#
# [5 rows x 47 columns]

# %%
df.shape
# Out:
# (121057, 47)

# %%
# Number of previous K lines to include
num_k_line = 24  # 6 hr

# Create a list to hold the lagged DataFrames
lagged_data = []

# Add the original columns with a suffix indicating the lag (0 for the original values)
for i in range(1, num_k_line + 1):
    lagged_df = df.drop(columns='label').shift(i).add_suffix(f'_lag_{i}')
    lagged_data.append(lagged_df)

# Concatenate all the lagged DataFrames along the columns
df_lagged = pd.concat(lagged_data, axis=1)
df = pd.concat([df, df_lagged], axis=1)

testing_data = df.loc[df.index > '2023-06-30']

# Print shapes to verify the split
print(f'Training data shape: {training_data.shape}')
print(f'Testing data shape: {testing_data.shape}')
# Out:
# Training data shape: (80939, 1151)
# Testing data shape: (31196, 1151)

# %%
print(training_data)
print(testing_data)
# Out:
#                      label  btc_spot_open  btc_spot_high  btc_spot_low  \
# 2021-01-02 06:00:00    1.0       29589.99       29647.50      29450.00
# 2021-01-02 06:15:00    1.0       29640.65       29663.10      29547.83
# 2021-01-02 06:30:00    1.0       29659.47       29676.58      29537.11
# 2021-01-02 06:45:00    1.0       29598.46       29745.00      29593.58
# 2021-01-02 07:00:00    1.0       29709.06       29768.10      29675.82
# ...                    ...            ...            ...           ...
# 2023-06-29 23:00:00    1.0       30409.35       30418.00      30392.78
# 2023-06-29 23:15:00    1.0       30405.18       30485.08      30396.01
# 2023-06-29 23:30:00    1.0       30482.19       30526.42      30474.06
# 2023-06-29 23:45:00    1.0       30480.00       30480.00      30444.01
# 2023-06-30 00:00:00    1.0       30447.31       30474.57      30421.53
#
#                      btc_spot_close  btc_spot_volume  \
# 2021-01-02 06:00:00        29640.65       823.280290
# 2021-01-02 06:15:00        29659.47       553.565606
# 2021-01-02 06:30:00        29598.46       536.400632
# 2021-01-02 06:45:00        29709.07      1116.994292
# 2021-01-02 07:00:00        29764.91      1058.048256
# ...                             ...              ...
# 2023-06-29 23:00:00        30405.18       129.645550
# 2023-06-29 23:15:00        30482.19       157.566320
# 2023-06-29 23:30:00        30479.99       230.525320
# 2023-06-29 23:45:00        30447.31        84.061200
# 2023-06-30 00:00:00        30421.54       226.215720
#
#                      btc_spot_quote_asset_volume  btc_spot_number_of_trades  \
# 2021-01-02 06:00:00                 2.434791e+07                    15640.0
# 2021-01-02 06:15:00                 1.638788e+07                    14616.0
# 2021-01-02 06:30:00                 1.588963e+07                    11769.0
# 2021-01-02 06:45:00                 3.316573e+07                    19088.0
# 2021-01-02 07:00:00                 3.146510e+07                    15744.0
# ...                                          ...                        ...
# 2023-06-29 23:00:00                 3.942170e+06                     4228.0
# 2023-06-29 23:15:00                 4.797730e+06                     5076.0
# 2023-06-29 23:30:00                 7.030539e+06                     6187.0
# 2023-06-29 23:45:00                 2.560554e+06                     3694.0
# 2023-06-30 00:00:00                 6.887575e+06                     6260.0
#
#                      btc_spot_taker_buy_base_asset_volume  \
# 2021-01-02 06:00:00                            604.785858
# 2021-01-02 06:15:00                            293.560533
# 2021-01-02 06:30:00                            311.656935
# 2021-01-02 06:45:00                            709.613955
# 2021-01-02 07:00:00                            785.838396
# ...                                                   ...
# 2023-06-29 23:00:00                             59.626950
# 2023-06-29 23:15:00                            107.537210
# 2023-06-29 23:30:00                            157.546950
# 2023-06-29 23:45:00                             27.230110
# 2023-06-30 00:00:00                             89.555730
#
#                      btc_spot_taker_buy_quote_asset_volume  ...   obv_lag_24  \
# 2021-01-02 06:00:00                           1.789109e+07  ...    12171.239
# 2021-01-02 06:15:00                           8.691268e+06  ...     6618.274
# 2021-01-02 06:30:00                           9.233140e+06  ...     9165.088
training_data
# Out:
# array([[1.        , 0.26383976, 0.2638687 , ..., 0.25764243, 0.25815469,
#         0.25856496],
#        [1.        , 0.26479847, 0.26416409, ..., 0.25764243, 0.25815469,
#         0.25856496],
#        [1.        , 0.26515463, 0.26441933, ..., 0.25764243, 0.25815469,
#         0.25856496],
#        ...,
#        [1.        , 0.28072413, 0.28051106, ..., 0.28032943, 0.28096271,
#         0.2815038 ],
#        [1.        , 0.28068269, 0.27963209, ..., 0.28032943, 0.28096271,
#         0.2815038 ],
#        [1.        , 0.28006405, 0.27952928, ..., 0.28032943, 0.28096271,
#         0.2815038 ]])

# %% [markdown]
# ### Prepared data for LSTM model

# %%
# Remove the first column (true labels)
X_train = training_data[:, 1:]
y_train = training_data[:, 0]
X_test = testing_data[:, 1:]
y_test = testing_data[:, 0]

# Reshape to [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], 25, -1)
y_train = y_train.reshape(y_train.shape[0], 1)
X_test = X_test.reshape(X_test.shape[0], 25, -1)
y_test = y_test.reshape(y_test.shape[0], 1)

# %%
print(X_train)
print(X_train.shape)
print(y_train)
print(y_train.shape)
print(X_test)
print(X_test.shape)
print(y_test)
print(y_test.shape)
# Out:
# [[[0.26383976 0.2638687  0.26479129 ... 0.25794362 0.25838581 0.2587084 ]
#   [0.26141882 0.26217232 0.26537094 ... 0.25764243 0.25815469 0.25856496]
#   [0.26134276 0.26141667 0.26400679 ... 0.25764243 0.25815469 0.25856496]
#   ...
#   [0.25219227 0.25306748 0.25472587 ... 0.25764243 0.25815469 0.25856496]
#   [0.25741719 0.25517058 0.25414176 ... 0.25764243 0.25815469 0.25856496]
#   [0.25783493 0.25571592 0.25890914 ... 0.25764243 0.25815469 0.25856496]]
#
#  [[0.26479847 0.26416409 0.26664505 ... 0.25813706 0.25853425 0.25880053]
#   [0.26311716 0.26325857 0.26469679 ... 0.25794362 0.25838581 0.2587084 ]
#   [0.26141882 0.26217232 0.26445568 ... 0.25764243 0.25815469 0.25856496]
#   ...
#   [0.25515737 0.2532026  0.25755792 ... 0.25764243 0.25815469 0.25856496]
#   [0.25219227 0.25306748 0.25472587 ... 0.25764243 0.25815469 0.25856496]
#   [0.25741719 0.25517058 0.25414176 ... 0.25764243 0.25815469 0.25856496]]
#
#  [[0.26515463 0.26441933 0.26644192 ... 0.25813706 0.25853425 0.25880053]
#   [0.26407325 0.26355327 0.26654989 ... 0.25813706 0.25853425 0.25880053]
#   [0.26311716 0.26325857 0.26378386 ... 0.25794362 0.25838581 0.2587084 ]
#   ...
#   [0.25531433 0.25316525 0.2570372  ... 0.25764243 0.25815469 0.25856496]
#   [0.25515737 0.2532026  0.25755792 ... 0.25764243 0.25815469 0.25856496]
#   [0.25219227 0.25306748 0.25472587 ... 0.25764243 0.25815469 0.25856496]]
#
#  ...
#
#  [[0.28072413 0.28051106 0.28419605 ... 0.28256851 0.28374236 0.28495584]
#   [0.27850191 0.27908147 0.2826162  ... 0.28256851 0.28374236 0.28495584]
#   [0.27858061 0.27781425 0.28158049 ... 0.28256851 0.28374236 0.28495584]
#   ...
#  [[1.01581514 1.01517565 1.01978071 ... 1.0363399  1.04169332 1.04745154]
#   [1.013268   1.01309823 1.01980453 ... 1.0363399  1.04169332 1.04745154]
#   [1.01319855 1.01324407 1.01621098 ... 1.0363399  1.04169332 1.04745154]
#   ...
#   [1.01401452 1.00882    1.01754603 ... 1.03173502 1.03454978 1.03714507]
#   [1.01313796 1.00868225 1.01614991 ... 1.03666198 1.0383305  1.03949148]
#   [1.01363559 1.00878115 1.01765754 ... 1.03801703 1.03937031 1.04013681]]
#
#  [[1.01539256 1.01535401 1.01977029 ... 1.0363399  1.04169332 1.04745154]
#   [1.01303304 1.01282827 1.01941678 ... 1.0363399  1.04169332 1.04745154]
#   [1.013268   1.01309823 1.01628725 ... 1.0363399  1.04169332 1.04745154]
#   ...
#   [1.01358773 1.00900766 1.01798166 ... 1.03028518 1.03394849 1.03760366]
#   [1.01401452 1.00882    1.01754603 ... 1.03173502 1.03454978 1.03714507]
#   [1.01313796 1.00868225 1.01614991 ... 1.03666198 1.0383305  1.03949148]]
#
#  [[1.0159936  1.01535401 1.02004334 ... 1.0363399  1.04169332 1.04745154]
#   [1.01261161 1.01300623 1.01940636 ... 1.0363399  1.04169332 1.04745154]
#   [1.01303304 1.01282827 1.01590084 ... 1.0363399  1.04169332 1.04745154]
#   ...
#   [1.01434145 1.00900766 1.01788507 ... 1.0333077  1.03770073 1.04226354]
#   [1.01358773 1.00900766 1.01798166 ... 1.03028518 1.03394849 1.03760366]
#   [1.01401452 1.00882    1.01754603 ... 1.03173502 1.03454978 1.03714507]]]
# (31196, 25, 46)
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]
# (31196, 1)

# %%
# Convert to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

print(X_train)
print(X_train.shape)
# Out:
# tensor([[[0.2638, 0.2639, 0.2648,  ..., 0.2579, 0.2584, 0.2587],
#          [0.2614, 0.2622, 0.2654,  ..., 0.2576, 0.2582, 0.2586],
#          [0.2613, 0.2614, 0.2640,  ..., 0.2576, 0.2582, 0.2586],
#          ...,
#          [0.2522, 0.2531, 0.2547,  ..., 0.2576, 0.2582, 0.2586],
#          [0.2574, 0.2552, 0.2541,  ..., 0.2576, 0.2582, 0.2586],
#          [0.2578, 0.2557, 0.2589,  ..., 0.2576, 0.2582, 0.2586]],
#
#         [[0.2648, 0.2642, 0.2666,  ..., 0.2581, 0.2585, 0.2588],
#          [0.2631, 0.2633, 0.2647,  ..., 0.2579, 0.2584, 0.2587],
#          [0.2614, 0.2622, 0.2645,  ..., 0.2576, 0.2582, 0.2586],
#          ...,
#          [0.2552, 0.2532, 0.2576,  ..., 0.2576, 0.2582, 0.2586],
#          [0.2522, 0.2531, 0.2547,  ..., 0.2576, 0.2582, 0.2586],
#          [0.2574, 0.2552, 0.2541,  ..., 0.2576, 0.2582, 0.2586]],
#
#         [[0.2652, 0.2644, 0.2664,  ..., 0.2581, 0.2585, 0.2588],
#          [0.2641, 0.2636, 0.2665,  ..., 0.2581, 0.2585, 0.2588],
#          [0.2631, 0.2633, 0.2638,  ..., 0.2579, 0.2584, 0.2587],
#          ...,
#          [0.2553, 0.2532, 0.2570,  ..., 0.2576, 0.2582, 0.2586],
#          [0.2552, 0.2532, 0.2576,  ..., 0.2576, 0.2582, 0.2586],
#          [0.2522, 0.2531, 0.2547,  ..., 0.2576, 0.2582, 0.2586]],
#
#         ...,
#
#         [[0.2807, 0.2805, 0.2842,  ..., 0.2826, 0.2837, 0.2850],
#          [0.2785, 0.2791, 0.2826,  ..., 0.2826, 0.2837, 0.2850],
#          [0.2786, 0.2778, 0.2816,  ..., 0.2826, 0.2837, 0.2850],
#          ...,
#          [0.2807, 0.2786, 0.2835,  ..., 0.2803, 0.2810, 0.2815],
#          [0.2811, 0.2789, 0.2839,  ..., 0.2803, 0.2810, 0.2815],
#          [0.2825, 0.2806, 0.2843,  ..., 0.2803, 0.2810, 0.2815]],
#
#         [[0.2807, 0.2796, 0.2836,  ..., 0.2826, 0.2837, 0.2850],
#          [0.2800, 0.2799, 0.2841,  ..., 0.2826, 0.2837, 0.2850],
#          [0.2785, 0.2791, 0.2816,  ..., 0.2826, 0.2837, 0.2850],
#          ...,
#          [0.2803, 0.2791, 0.2838,  ..., 0.2803, 0.2810, 0.2815],
#          [0.2807, 0.2786, 0.2835,  ..., 0.2803, 0.2810, 0.2815],
#          [0.2811, 0.2789, 0.2839,  ..., 0.2803, 0.2810, 0.2815]],
#
#         [[0.2801, 0.2795, 0.2832,  ..., 0.2826, 0.2837, 0.2850],
#          [0.2799, 0.2790, 0.2835,  ..., 0.2826, 0.2837, 0.2850],
#          [0.2800, 0.2799, 0.2831,  ..., 0.2826, 0.2837, 0.2850],
#          ...,
#          [0.2811, 0.2797, 0.2846,  ..., 0.2803, 0.2810, 0.2815],
#          [0.2803, 0.2791, 0.2838,  ..., 0.2803, 0.2810, 0.2815],
#          [0.2807, 0.2786, 0.2835,  ..., 0.2803, 0.2810, 0.2815]]])
# torch.Size([80939, 25, 46])

# %%
# Create DataLoader
train_data = TensorDataset(X_train, y_train)
test_data = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_data, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# %%
one_train = next(iter(train_loader))
print(one_train[0].shape)
print(one_train[1].shape)
# Out:
# torch.Size([32, 25, 46])
# torch.Size([32, 1])

# %% [markdown]
# ## Build LSTM Model

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_layer_size=50, output_size=1):
        super().__init__()
        self.hidden_layer_size = hidden_layer_size
        self.drop_out = nn.Dropout(p=0.5)
        self.lstm = nn.LSTM(input_size, hidden_layer_size, batch_first=True)
        self.linear = nn.Linear(hidden_layer_size, output_size)
        self.sigmoid = nn.Sigmoid()  # Sigmoid activation function

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        out = lstm_out[:, -1, :]
        out = self.drop_out(out)
        linear_out = self.linear(out)
        predictions = self.sigmoid(linear_out)  # Apply sigmoid activation
        return predictions

# %%
# hyperparameters
input_size = X_train.shape[2]
hidden_layer_size = 128
output_size = 1 # Binary classification
learning_rate = 0.001

# %%
# Initialize model and move it to the GPU
model = LSTM(input_size, hidden_layer_size, output_size).to(device)
loss_function = nn.BCELoss().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Training & Testing

# %%
# recording losses and accuracies for each epoch
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []

# %%
epochs = 50

# Training model
for epoch in range(epochs):
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        y_pred = model(X_batch)
        loss = loss_function(y_pred, y_batch)
        loss.backward()

        # Gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step()
        train_loss += loss.item()

        # Calculate accuracy
        predicted = (y_pred > 0.5).float()
        correct_train += (predicted == y_batch).sum().item()
        total_train += y_batch.size(0)

    train_losses.append(train_loss / len(train_loader))
    train_accuracy = 100 * correct_train / total_train
    train_accuracies.append(train_accuracy)

    model.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    predictions = []
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch)
            loss = loss_function(y_pred, y_batch)
            test_loss += loss.item()

            # Calculate accuracy
            predicted = (y_pred >= 0.5).float()
            predictions.extend(predicted.cpu().numpy())
            correct_test += (predicted == y_batch).sum().item()
            total_test += y_batch.size(0)

    test_losses.append(test_loss / len(test_loader))
    test_accuracy = 100 * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f'Epoch {epoch+1}/{epochs}, Training Loss: {train_losses[-1]}, Testing Loss: {test_losses[-1]}, Training Accuracy: {train_accuracy}%, Testing Accuracy: {test_accuracy}%')
# Out:
# Epoch 1/50, Training Loss: 0.6688024881697101, Testing Loss: 0.6577509376635918, Training Accuracy: 64.24467809090797%, Testing Accuracy: 63.37992050262854%
# Epoch 2/50, Training Loss: 0.6575316897258457, Testing Loss: 0.6598510896548246, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 3/50, Training Loss: 0.6552645198205714, Testing Loss: 0.6605429252600058, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 4/50, Training Loss: 0.6540528629078224, Testing Loss: 0.6603737697845851, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 5/50, Training Loss: 0.6536912449852751, Testing Loss: 0.6604794800892855, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 6/50, Training Loss: 0.6533482846181854, Testing Loss: 0.6600406323029445, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 7/50, Training Loss: 0.6542220726785923, Testing Loss: 0.6612259601324032, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 8/50, Training Loss: 0.653291762664384, Testing Loss: 0.6594189979785527, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 9/50, Training Loss: 0.6526569330998561, Testing Loss: 0.6589348560724503, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 10/50, Training Loss: 0.6523682623159273, Testing Loss: 0.6586626436160161, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 11/50, Training Loss: 0.6521792000461473, Testing Loss: 0.6584403056976122, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 12/50, Training Loss: 0.6524456871651378, Testing Loss: 0.6582701657062922, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 13/50, Training Loss: 0.6518265453487517, Testing Loss: 0.6579677999019623, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 14/50, Training Loss: 0.6520133223752731, Testing Loss: 0.657721126874288, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 15/50, Training Loss: 0.650753802308452, Testing Loss: 0.6574236510350154, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 16/50, Training Loss: 0.6510867251709045, Testing Loss: 0.6564560166383401, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch 17/50, Training Loss: 0.6502143055612862, Testing Loss: 0.658268196063164, Training Accuracy: 64.30274651280594%, Testing Accuracy: 63.37992050262854%
# Epoch 18/50, Training Loss: 0.6518340423644295, Testing Loss: 0.6555290746688843, Training Accuracy: 64.3200434895415%, Testing Accuracy: 63.37992050262854%
# Epoch
# Epoch 40/50, Training Loss: 0.5710446573249083, Testing Loss: 0.6250564046318714, Training Accuracy: 68.0648389527916%, Testing Accuracy: 64.67816386716245%
# Epoch 41/50, Training Loss: 0.5698594222084542, Testing Loss: 0.6182724382117009, Training Accuracy: 68.27610916863317%, Testing Accuracy: 64.68778048467752%
# Epoch 42/50, Training Loss: 0.5672762727228696, Testing Loss: 0.6215319250008234, Training Accuracy: 68.39471700910562%, Testing Accuracy: 64.74227465059623%
# Epoch 43/50, Training Loss: 0.5663342972466421, Testing Loss: 0.6136443803134637, Training Accuracy: 68.55780278975524%, Testing Accuracy: 64.61725862290037%
# Epoch 44/50, Training Loss: 0.5639775532183675, Testing Loss: 0.6186087737862881, Training Accuracy: 68.59980973325591%, Testing Accuracy: 64.6076420053853%
# Epoch 45/50, Training Loss: 0.563235982466975, Testing Loss: 0.6244414438288182, Training Accuracy: 68.99393370315917%, Testing Accuracy: 64.37684318502372%
# Epoch 46/50, Training Loss: 0.561978388707275, Testing Loss: 0.6123613413442404, Training Accuracy: 69.03964714167459%, Testing Accuracy: 64.67175278881908%
# Epoch 47/50, Training Loss: 0.5625720502863907, Testing Loss: 0.6187426803261041, Training Accuracy: 68.95069126132026%, Testing Accuracy: 64.57238107449673%
# Epoch 48/50, Training Loss: 0.5608473467986603, Testing Loss: 0.6133510203984304, Training Accuracy: 69.17678745722087%, Testing Accuracy: 64.79356327734325%
# Epoch 49/50, Training Loss: 0.5575410806036485, Testing Loss: 0.6146770836069033, Training Accuracy: 69.4597165766812%, Testing Accuracy: 65.0339787152199%
# Epoch 50/50, Training Loss: 0.5572570234467183, Testing Loss: 0.6157823467980593, Training Accuracy: 69.47701355341677%, Testing Accuracy: 64.950634696756%

# %% [markdown]
# ### Visualize data

# %%
# Plotting the training loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.show()

# %%
# Plotting the training accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Training Accuracy Over Epochs')
plt.legend()
plt.show()

# %%
# Plotting the testing loss
plt.figure(figsize=(10, 5))
plt.plot(test_losses, label='Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Testing Loss Over Epochs')
plt.legend()
plt.show()

# %%
# Plotting the testing accuracy
plt.figure(figsize=(10, 5))
plt.plot(test_accuracies, label='Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Testing Accuracy Over Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## Output result

# %%
# Save testing results to CSV
df_pred = pd.DataFrame({'prediction': predictions})
df_pred = df_pred['prediction'].apply(lambda x: x[0])
df_pred.index = df.loc[df.index > '2023-06-30'].index
df_pred
# Out:
# 2023-06-30 00:15:00    0.0
# 2023-06-30 00:30:00    0.0
# 2023-06-30 00:45:00    0.0
# 2023-06-30 01:00:00    0.0
# 2023-06-30 01:15:00    0.0
#                       ...
# 2024-06-08 22:45:00    1.0
# 2024-06-08 23:00:00    1.0
# 2024-06-08 23:15:00    1.0
# 2024-06-08 23:30:00    1.0
# 2024-06-08 23:45:00    1.0
# Name: prediction, Length: 31196, dtype: float32

# %%
df_pred.to_csv('data/testing_results.csv', index=True)
print('Testing results saved to data/testing_results.csv')
# Out:
# Testing results saved to data/testing_results.csv
